# %% [markdown]
# #### Importing

# %%
import pandas as pd
#import unittest 
from pandas.util.testing import assert_frame_equal

# %% [markdown]
# #### Reading in data

# %%
pscore = pd.read_csv('personality_scores.csv',delimiter=";")
pscore.dropna(axis='columns').head(2)
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# 1                               (5, 5)
#
#   Section 5 of 6 [I am interested in people.]  \
# 0                                      (2, 3)
# 1                                      (2, 5)
#
#   Section 5 of 6 [I am not interested in abstract ideas.]  \
# 0                                             (5, 3)
# 1                                             (5, 3)
#
#   Section 5 of 6 [I am not interested in other people's problems.]  \
# ...

# %% [markdown]
# #### Examining datasets for duplicates

# %%
# sorting by first name 
pscore.sort_values("ID", inplace = True)
pscore

# dropping ALL duplicte values 
dropped_pscore = pscore.drop_duplicates(subset ="ID", 
                     keep = False, inplace = False) 
len(dropped_pscore)
# Out:
# 1555

# %% [markdown]
# #### Checking the lengths of the datasets using assert

# %%
#assertEqual(pscore, dropped_pscore)

def same(length):
    assert len(pscore) == len(dropped_pscore)
    return True
       
same('')
# Out:
# True

# %% [markdown]
# #### Creating columns containing the total score of each of the personality test subscales

# %%
def assigning(row,Category_Num):
    count = 0
    asd = 0
    for column in dropped_pscore.columns:
        tuplee = row[column]
        if type(tuplee) == str:
            catergory = tuplee[1]
            result = int(tuplee[4])
            if catergory == Category_Num:
                count += result
    return count

# %%
dropped_pscore['Extraversion'] = dropped_pscore.apply(lambda row : assigning(row,'1'), axis = 1)
dropped_pscore['Agreeableness'] = dropped_pscore.apply(lambda row : assigning(row,'2'), axis = 1)
dropped_pscore['Conscientiousness'] = dropped_pscore.apply(lambda row : assigning(row,'3'), axis = 1)
dropped_pscore['Emotional Stability'] = dropped_pscore.apply(lambda row : assigning(row,'4'), axis = 1)
dropped_pscore['Openness to experiences'] = dropped_pscore.apply(lambda row : assigning(row,'5'), axis = 1)

# %%
dropped_pscore.head()
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %% [markdown]
# #### Importing department dataset

# %%
department = pd.read_csv('/home/recruit/Desktop/dw/departments .csv',delimiter=";")
department.head()
# Out:
#    ID Department
# 0   0       Data
# 1   1       Data
# 2   2       Data
# 3   3       Data
# 4   4       Data

# %%
department.shape
# Out:
# (1555, 2)

# %% [markdown]
# #### Checking for nan values in dataset

# %%
department.isnull().sum()
# Out:
# ID;Department    0
# dtype: int64

# %% [markdown]
# #### Merging Department dataframe with the personality score dataframe

# %%
combined_data = pd.merge(left=dropped_pscore, right=department, left_on='ID', right_on='ID')

combined_data.head()
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %%
def sameLength(length):
    assert len(department) == len(combined_data)
    return True
       
sameLength('')
# Out:
# True
